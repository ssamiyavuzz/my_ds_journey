# %% [markdown]
# # Multiple Linear Regression and Regression Error Metrics

# %%
# y = b0 + b1X1 + b2X2 + b3X3 multiple linear regress

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
 # !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\anaconda\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from missingno) (1.24.3)
# Requirement already satisfied: matplotlib in c:\anaconda\lib\site-packages (from missingno) (3.7.2)
# Requirement already satisfied: scipy in c:\anaconda\lib\site-packages (from missingno) (1.11.1)
# Requirement already satisfied: seaborn in c:\anaconda\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\anaconda\lib\site-packages (from seaborn->missingno) (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno

# %%
msno.matrix(df);

# %% [markdown]
# **örnek null hucreleri olan bir resim (farklı bir data setinden alınmıştır)**
#
# ![image%20%2811%29.png](attachment:image%20%2811%29.png)

# %%
df.sort_values(by="sales", ascending=False)
# Out:
#         TV  radio  newspaper  sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
# !pip install summarytools
# Out:
# Requirement already satisfied: summarytools in c:\anaconda\lib\site-packages (0.2.3)
# Requirement already satisfied: pandas>=1.4.0 in c:\anaconda\lib\site-packages (from summarytools) (2.0.3)
# Requirement already satisfied: ipython>=7.20.0 in c:\anaconda\lib\site-packages (from summarytools) (8.15.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\anaconda\lib\site-packages (from summarytools) (1.24.3)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\anaconda\lib\site-packages (from summarytools) (3.7.2)
# Requirement already satisfied: backcall in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: decorator in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.1.6)
# Requirement already satisfied: pickleshare in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (2.15.1)
# Requirement already satisfied: stack-data in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (5.7.1)
# Requirement already satisfied: colorama in c:\anaconda\lib\site-packages (from ipython>=7.20.0->summarytools) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda\lib\site-packages (from pandas>=1.4.0->summarytools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\anaconda\lib\site-packages (from pandas>=1.4.0->summarytools) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: wcwidth in c:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.20.0->summarytools) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# Requirement already satisfied: executing in c:\anaconda\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: asttokens in c:\anaconda\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.0.5)
# Requirement already satisfied: pure-eval in c:\anaconda\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.2.2)

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_051f6 thead>tr>th {
#   text-align: left;
# }
# #T_051f6_row0_col0, #T_051f6_row1_col0, #T_051f6_row2_col0, #T_051f6_row3_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_051f6_row0_col1, #T_051f6_row1_col1, #T_051f6_row2_col1, #T_051f6_row3_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_051f6_row0_col2, #T_051f6_row1_col2, #T_051f6_row2_col2, #T_051f6_row3_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_051f6_row0_col3, #T_051f6_row1_col3, #T_051f6_row2_col3, #T_051f6_row3_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_051f6_row0_col4, #T_051f6_row1_col4, #T_051f6_row2_col4, #T_051f6_row3_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_051f6_row0_col5, #T_051f6_row1_col5, #T_051f6_row2_col5, #T_051f6_row3_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_051f6">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 200 x 4<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_051f6_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_051f6_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_051f6_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_051f6_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_051f6_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_051f6_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_051f6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_051f6_row0_col1" class="data row0 col1" ><strong>TV</strong><br>[float64]</td>
#       <td id="T_051f6_row0_col2" class="data row0 col2" >Mean (sd) : 147.0 (85.9)<br>min < med < max:<br>0.7 < 149.8 < 296.4<br>IQR (CV) : 144.4 (1.7)</td>
#       <td id="T_051f6_row0_col3" class="data row0 col3" >190 distinct values</td>
#       <td id="T_051f6_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_051f6_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_051f6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_051f6_row1_col1" class="data row1 col1" ><strong>radio</strong><br>[float64]</td>
#       <td id="T_051f6_row1_col2" class="data row1 col2" >Mean (sd) : 23.3 (14.8)<br>min < med < max:<br>0.0 < 22.9 < 49.6<br>IQR (CV) : 26.5 (1.6)</td>
#       <td id="T_051f6_row1_col3" class="data row1 col3" >167 distinct values</td>
#       <td id="T_051f6_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_051f6_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_051f6_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_051f6_row2_col1" class="data row2 col1" ><strong>newspaper</strong><br>[float64]</td>
#       <td id="T_051f6_row2_col2" class="data row2 col2" >Mean (sd) : 30.6 (21.8)<br>min < med < max:<br>0.3 < 25.8 < 114.0<br>IQR (CV) : 32.4 (1.4)</td>
#       <td id="T_051f6_row2_col3" class="data row2 col3" >172 distinct values</td>
#       <td id="T_051f6_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_051f6_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_051f6_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_051f6_row3_col1" class="data row3 col1" ><strong>sales</strong><br>[float64]</td>
#       <td id="T_051f6_row3_col2" class="data row3 col2" >Mean (sd) : 14.0 (5.2)<br>min < med < max:<br>1.6 < 12.9 < 27.0<br>IQR (CV) : 7.0 (2.7)</td>
#       <td id="T_051f6_row3_col3" class="data row3 col3" >121 distinct values</td>
#       <td id="T_051f6_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_051f6_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mean ve Std değerleenini birbirine yakınlığının outlier tespitindeki önemi hakkında bir örnek

print ( np.mean([100,110,120,115]))
print ( np.std([100,110,120,115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print ( np.mean([100,110,120,700]))
print ( np.std([100,110,120,700]))
# Out:
# 257.5
# 255.57533136044253

# %%
sns.pairplot(df);

# %%
sns.heatmap(df.corr(), annot=True);

# %%
from scipy.stats import skew

# %% [markdown]
# ![image%20%2812%29.png](attachment:image%20%2812%29.png)

# %%
# skewness tespiti için bir döngü
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))
# sales sütunu haricindeki tüm feature ların skewness degerini hesplar
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %% [markdown]
# - -0.5 ile + 0.5 arasındaki skewness degerlerinde dagılımın kabaca simetrik oldugu kabul edilebilir

# %%
for j in df.drop(columns = "sales").columns:     #"sales" sütunu dataframe'den kaldırılıyor
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))   #  j sütununa ait veri dağılımı grafiği çiziliyor. grafiğin üzerinde gösterilen etiketi oluşturur. Etiket, o sütunun çarpıklık değerini (skewness) içerir
    g = g.legend(loc= "best")   #  grafiğin üzerine eklenen etiketin konumunu en iyi yere yerleştirmes
    plt.show()

# %% [markdown]
# # Train-Test Split

# %%
# ML için kullanılan kütüphane Scikit-learn kütüphanesi
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\anaconda\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\anaconda\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\anaconda\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda\lib\site-packages (from scikit-learn) (2.2.0)

# %%
X = df.drop(columns="sales") # Indep variable'ları X'e atadık
y = df["sales"] # modelin önüne hedef olarak target variable atadık
print(X,y)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
# Veri setini randomly olarak eğitim(training) ve test(testing) alt 
# kümelerine ayırmak için kullanılır

from sklearn.model_selection import train_test_split

# %% [markdown]
# X_train: Eğitim veri setinin özelliklerini (features) içerir.
#
# X_test: Test veri setinin özelliklerini (features) içerir.
#
# y_train: Eğitim veri setinin etiketlerini (labels/targets) içerir.
#
# y_test: Test veri setinin etiketlerini (labels/targets) içerir.
#
# train_test_split(X, y, test_size=0.3, random_state=42): Bu fonksiyon çağrısı ile X (özellikler) ve y (etiketler) veri setleri
# rastgele olarak eğitim ve test alt kümelerine ayrılır.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %% [markdown]
# ![image%20%2813%29.png](attachment:image%20%2813%29.png)

# %% [markdown]
# ![x_train_x%20test.gif](attachment:x_train_x%20test.gif)

# %%
df.sample(15)
# Out:
#         TV  radio  newspaper  sales
# 181  218.5    5.4       27.4   12.2
# 136   25.6   39.0        9.3    9.5
# 141  193.7   35.4       75.6   19.2
# 142  220.5   33.2       37.9   20.1
# 183  287.6   43.0       71.8   26.2
# 68   237.4   27.5       11.0   18.9
# 92   217.7   33.5       59.0   19.4
# 72    26.8   33.0       19.3    8.8
# 102  280.2   10.1       21.4   14.8
# 22    13.2   15.9       49.6    5.6
# 134   36.9   38.6       65.6   10.8
# 125   87.2   11.8       25.9   10.6
# 135   48.3   47.0        8.5   11.6
# 71   109.8   14.3       31.7   12.4
# 169  284.3   10.6        6.4   15.0

# %% [markdown]
# ![X-test-x-train-2.png](attachment:X-test-x-train-2.png)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# Y Test features shape : (60,)

# %%
#Print("Train features shape: ", X_train.shape)
#Print("Train target shape: ", y_train.shape)
#Print("Test features shape: ", X_test.shape)
#Print("Test target shape: ", y_test.shape)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 140, dtype: float64

# %%
X_test
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# 18    69.2   20.5       18.3
# 55   198.9   49.4       60.0
# 75    16.9   43.7       89.4
# 150  280.7   13.9       37.0
# 104  238.2   34.3        5.3
# 135   48.3   47.0        8.5
# 137  273.7   28.9       59.7
# 164  117.2   14.7        5.4
# 76    27.5    1.6       20.7
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# 195   38.2    3.7       13.8
# 29    70.6   16.0       40.8
# 19   147.3   23.9       19.1
# 143  104.6    5.7       34.4
# 86    76.3   27.5       16.0
# 114   78.2   46.8       34.5
# 173  168.4    7.1       12.8
# 5      8.7   48.9       75.0
# 126    7.8   38.9       50.6
# 117   76.4    0.8       14.8
# 73   129.4    5.7       31.3
# 140   73.4   17.0       12.9
# 98   289.7   42.3       51.2
# 172   19.6   20.1       17.0
# 96   197.6    3.5        5.9

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
# 195     7.6
# 29     10.5
# 19     14.6
# 143    10.4
# 86     12.0
# 114    14.6
# 173    11.7
# 5       7.2
# 126     6.6
# 117     9.4
# 73     11.0
# 140    10.9
# 98     25.4
# 172     7.6
# 96     11.7
# Name: sales, dtype: float64

# %% [markdown]
# # Model Fitting and Compare Actual and Predicted Labels

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
model.coef_ # modelin katsayılarını verir (TV:0.04, radio:0.199, newsp:0.006)
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.feature_names_in_ # yukaridaki katsayilarin karsilik geldigi feature lari verir
# Out:
# array(['TV', 'radio', 'newspaper'], dtype=object)

# %%
model.intercept_ # modeldeki sabit sayı
# Out:
# 2.70894909251591

# %% [markdown]
# y_pred = b1 * TV + b2 * radio +b3 * newspaper + b0

# %%
# herhangi bir satırdaki degerler için tahmin yapalım..manuel olarak y_pred hesapladım
# bu deger y_test kümesindeki 95. satir degeri olan 16.9 gercek degerinin manuel olarak tahmin edilen halidir

sum(X_test.loc[95]*model.coef_) + model.intercept_
# Out:
# 16.565396297434837

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual":y_test - y_pred}
# Actual: gercek deger, pred: tahmin edilen deger, residual: gercek deger - tahmin edilen deger

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393
# 60      8.1   5.611980  2.488020
# 84     21.7  20.917595  0.782405
# 67     13.4  11.806277  1.593723
# 125    10.6   9.080766  1.519234
# 132     5.7   8.514120 -2.814120
# 9      10.6  12.176049 -1.576049
# 18     11.3   9.969194  1.330806
# 55     23.7  21.730090  1.969910
# 75      8.7  12.777706 -4.077706
# 150    16.1  18.101136 -2.001136
# 104    20.7  20.075908  0.624092
# 135    11.6  14.262026 -2.662026
# 137    20.8  20.938265 -0.138265
# 164    11.9  10.839388  1.060612
# 76      6.9   4.381906  2.518094
# 79     11.0   9.513324  1.486676
# 197    12.8  12.404863  0.395137
# 38     10.1  10.170454 -0.070454
# 24      9.7   8.090814  1.609186
# 122    11.6  13.163884 -1.563884
# 195     7.6   5.224355  2.375645
# 29     10.5   9.288938  1.211062
# 19     14.6  14.093307  0.506693
# 143    10.4   8.690245  1.709755
# 86     12.0  11.661198  0.338802
# 114    14.6  15.718484 -1.118484
# 173    11.7  11.631569  0.068431
# 5       7.2  13.353607 -6.153607
# 126     6.6  11.153147 -4.553147
# 117     9.4   6.336368  3.063632
# 73     11.0   9.761580  1.238420
# 140    10.9   9.419571  1.480429
# 98     25.4  24.255165  1.144835
# 172     7.6   7.695191 -0.095191
# 96     11.7  12.153176 -0.453176

# %%
result_sample = comparing.head(25)
result_sample
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393

# %%
result_sample.plot(kind= "bar", figsize = (15,9))
plt.show()

# %% [markdown]
# # Error Metrics

# %%
# modelin başarısını ölçelim

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# performans degerlendirme icin error metrikleri
# RMSE metrigini manuel hesaplayacagiz

# %%
R2_score = r2_score(y_test, y_pred)
R2_score
# Out:
# 0.8609466508230368

# %%
# Mean Absolute Error hesabı
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.5116692224549084

# %%
# Mean Squared Error hesabi

mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 3.79679723671522

# %%
# Root Mean Squared Error hesabı

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 1.9485372043446387

# %%
# Ortalama Hata Oranı

# %%
sales_mean = df["sales"].mean()
sales_mean
# Out:
# 14.0225

# %%
# MAE Hata Oranı - "0' a yakın olması iyi bir tahmin modeli oldugunu gösterir"
mae / sales_mean
# Out:
# 0.10780311802138764

# %%
# RMSE Hata Orani

rmse / sales_mean
# Out:
# 0.138957903679418

# %% [markdown]
# # Adjusted R2 Score (Düzeltilmiş R2 Değeri)

# %%
n = gözlem sayım (data noktası sayısı)
p = feature
Adjusted R2 = 1 - [(1 - R2) * (n - 1) / (n - p - 1)]
# Out:
#   Cell In[54], line 1
#     n = gözlem sayım (data noktası sayısı)
#                ^
# SyntaxError: invalid syntax

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)    #R2 scor
    n = df.shape[0]      # number of observations gözlem
    p =df.shape[1]-1    # number of indep. variable = feature
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)

# %%
# önceki r2 degerine yakın çıktı. çünkü zaten 3 feature vardı. alt örnekte feature sayısını abartıı vererek adjusted etkisini görelim

# %%
def adj_r2(y_test, y_pred, df):
    r2 = r2_score(y_test, y_pred)
    n = df.shape[0]   # number of observations
    p = 100 # number of independent variables ..feature sayısıı 100 aldık
    adj_r2 = 1 - (1-r2)*(n-1)/(n-p-1)
    return adj_r2

# %%
adj_r2(y_test, y_pred, df)

# %%
# bir görüşe göre, her eklenen feature için 10-15 gözlem satırı daha eklenmelidir

# %% [markdown]
# # Evaluation Model

# %%
# Error metricleri hesaplayan ve yazan kod blogu
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metric(y_test, y_pred)

# %%
# Overfitting kontrolü için train data daki R2 yi bulalım ve yukardak test R2 (0.86) ile karşılaştıralım

# %%
# X_train degerlerini prediction yapacağız
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x=y_test, y=residuals)
plt.xlabel("Sales")
plt.ylabel("Residuals")
plt.axhline(y=0, color = "r", linestyle = "--")
plt.show()

# %%
sns.kdeplot(residuals);

# %%
stats.probplot(residuals, dist="norm", plot=plt);

# %%
skew(residuals)
# Out:
# -0.9865673346742742

# %%
pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      ---------------------------------------- 0.0/282.6 kB ? eta -:--:--
#      - -------------------------------------- 10.2/282.6 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/282.6 kB 445.2 kB/s eta 0:00:01
#      ------------ ------------------------ 92.2/282.6 kB 751.6 kB/s eta 0:00:01
#      ------------------------------ ------- 225.3/282.6 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 282.6/282.6 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\anaconda\lib\site-packages (from yellowbrick) (3.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\anaconda\lib\site-packages (from yellowbrick) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\anaconda\lib\site-packages (from yellowbrick) (1.3.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\anaconda\lib\site-packages (from yellowbrick) (1.24.3)
# Requirement already satisfied: cycler>=0.10.0 in c:\anaconda\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from yellowbrick.regressor import ResidualsPlot

# %%
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
from yellowbrick.regressor import PredictionError

model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
final_model = LinearRegression()
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
final_model.feature_names_in_
# Out:
# array(['TV', 'radio', 'newspaper'], dtype=object)

# %%
coeff_df = pd.DataFrame(final_model.coef_, index = X.columns, columns = ["Coefficient"] )

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
final_model.intercept_
# Out:
# 2.9388893694594067

# %%
coeff_df
# Out:
#            Coefficient
# TV            0.045765
# radio         0.188530
# newspaper    -0.001037

# %%
adv = [[150, 20, 15]]

# %%
final_model.predict(adv)
# Out:
# array([13.55862413])

# %%
sum(final_model.coef_ * [150, 20, 15]) + final_model.intercept_  # yeni datanın değerini manuel olarak sağlamasını yaptık.
# Out:
# 13.558624130495994

# %%
adv_2 = [[150, 20, 15], [160, 20, 15]]

# %%
final_model.predict(adv_2)
# Out:
# array([13.55862413, 14.01627059])
